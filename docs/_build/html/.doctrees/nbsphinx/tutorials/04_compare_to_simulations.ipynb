# %% [markdown]
# ## Tutorial 4: Comparing Circuit Simulations to FEM Simulations
#
#
# This tutorial will show you how to compare touchstone files and full-wave FEM simulations to circuit-level lumped models.

# %% [markdown]
# ---
# This tutorial is not yet public. Please check back soon!
